# %%
import vicausi
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# ...

# %% [markdown]
# # Insomnia-Tiredness-Anxiety Example

# %%
# dags_presented = [0,1]
var_order = ['tiredness','anxiety','insomnia']
# var_order = ['tiredness','insomnia','anxiety']
var_order = ['anxiety','tiredness','insomnia'] 
# var_order = ['anxiety','insomnia','tiredness']
# var_order = ['insomnia','tiredness','anxiety']
# var_order = ['insomnia','anxiety','tiredness']
plot = vicausi.single_matrix_visualizer(["insomnia1.npz","insomnia0.npz"],0, var_order,"i_value",{"atomic":["anxiety","insomnia","tiredness"],"shift":["anxiety","insomnia","tiredness"],"variance":["anxiety","insomnia","tiredness"]} )
#{"atomic":["insomnia","anxiety","tiredness"],"shift":["insomnia","anxiety","tiredness"],"variance":["insomnia","anxiety","tiredness"]}
plot.get_plot().show()
# Out:
# Launching server at http://localhost:55631

# %% [markdown]
# ### The visualizations shown in the tasks of the user study on evaluating visualization of probabilistic simulated interventions (https://github.com/evdoxiataka/simulated_interventions_study_analysis)

# %%
#t1
var_order = ['anxiety','tiredness','insomnia'] 
plot = vicausi.single_matrix_visualizer(["insomnia0.npz","insomnia2.npz"],0, var_order,"i_value",{"atomic":["tiredness"]} )
plot.get_plot().show()
# Out:
# Launching server at http://localhost:64437

# %%
#t2
var_order = ['insomnia','anxiety','tiredness']
plot = vicausi.single_matrix_visualizer(["insomnia1.npz","insomnia0.npz"],1, var_order,"i_value",{"atomic":["insomnia"]} )
plot.get_plot().show()
# Out:
# Launching server at http://localhost:58423

# %%
#t3
var_order = ['tiredness','anxiety','insomnia']
plot = vicausi.single_matrix_visualizer(["insomnia1.npz","insomnia2.npz"],0, var_order,"static",{"atomic":["anxiety"]} )
plot.get_plot().show()

# %%
#t4
var_order = ['anxiety','insomnia','tiredness']
plot = vicausi.single_matrix_visualizer(["insomnia2.npz","insomnia1.npz"],0, var_order,"i_value",{"atomic":["tiredness"]} )
plot.get_plot().show()
# Out:
# Launching server at http://localhost:62000

# %%
#t5
var_order = ['tiredness','insomnia','anxiety']
plot = vicausi.single_matrix_visualizer(["insomnia0.npz","insomnia2.npz"],1, var_order,"i_value",{"atomic":["anxiety"]} )
plot.get_plot().show()
# Out:
# Launching server at http://localhost:62860

# %%
#t6
var_order = ['insomnia','anxiety','tiredness']
plot = vicausi.single_matrix_visualizer(["insomnia0.npz","insomnia2.npz"],1, var_order,"static",{"shift":["tiredness"]} )
plot.get_plot().show()
# Out:
# Launching server at http://localhost:63202
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='111566', ...)

# %%
#t7
var_order = ['insomnia','tiredness','anxiety']
plot = vicausi.single_matrix_visualizer(["insomnia2.npz","insomnia0.npz"],0, var_order,"i_value",{"shift":["anxiety"]} )
plot.get_plot().show()

# %%
#t8
var_order = ['tiredness','insomnia','anxiety']
plot = vicausi.single_matrix_visualizer(["insomnia0.npz","insomnia1.npz"],0, var_order,"i_value",{"variance":["anxiety"]} )
plot.get_plot().show()
# Out:
# Launching server at http://localhost:61690

# %%
#t9
var_order = ['insomnia','anxiety','tiredness']
plot = vicausi.single_matrix_visualizer(["insomnia0.npz","insomnia1.npz"],1, var_order,"i_value",{"variance":["insomnia"]} )
plot.get_plot().show()

# %%
#t10
var_order = ['insomnia','tiredness','anxiety']
plot = vicausi.single_matrix_visualizer(["insomnia1.npz","insomnia2.npz"],1, var_order,"i_value",{"variance":["anxiety"]} )
plot.get_plot().show()

# %%
#t11
var_order = ['insomnia','tiredness','anxiety']
plot = vicausi.single_matrix_visualizer(["insomnia0.npz","insomnia1.npz","insomnia2.npz"],1, var_order,"i_value",{"atomic":["insomnia","anxiety","tiredness"]} )
plot.get_plot().show()
# Out:
# Launching server at http://localhost:64523

# %%
#t12
var_order = ['insomnia','anxiety','tiredness']
plot = vicausi.single_matrix_visualizer(["insomnia1.npz","insomnia2.npz","insomnia0.npz"],2, var_order,"i_value",{"atomic":["insomnia","tiredness","anxiety"]} )
plot.get_plot().show()
# Out:
# Launching server at http://localhost:59652

# %%
#t13
var_order = ['tiredness','anxiety','insomnia']
plot = vicausi.single_matrix_visualizer(["insomnia2.npz","insomnia0.npz","insomnia1.npz"],2, var_order,"i_value",{"shift":["anxiety","insomnia","tiredness"]} )
plot.get_plot().show()

# %%
#t14
var_order = ['tiredness','insomnia','anxiety']
plot = vicausi.single_matrix_visualizer(["insomnia0.npz","insomnia1.npz","insomnia2.npz"],2, var_order,"i_value",{"shift":["anxiety","tiredness","insomnia"]} )
plot.get_plot().show()

# %%
#t15
var_order = ['anxiety','tiredness','insomnia'] 
plot = vicausi.single_matrix_visualizer(["insomnia2.npz","insomnia0.npz","insomnia1.npz"],1, var_order,"i_value",{"variance":["tiredness","anxiety","insomnia"]} )
plot.get_plot().show()

# %%
#t16
var_order = ['anxiety','insomnia','tiredness']
plot = vicausi.single_matrix_visualizer(["insomnia1.npz","insomnia0.npz","insomnia2.npz"],0, var_order,"animated",{"variance":["insomnia","tiredness","anxiety"]} )
plot.get_plot().show()
